# %%
import os as os
import pandas as pd
import xml.etree.ElementTree as ET
import numpy as np

path_parent = os.path.dirname(os.getcwd())
df = pd.read_csv(path_parent+"/Output/synonym.csv")

value = input("Search for synonym : ")

print(value)

df=df.loc[df['Synonym'].str.contains(value, na=False)]

df.head(20)
# Out:
# Search for synonym : Amino
# Amino
#      Unnamed: 0    Accession                  Name  \
# 0             0  HMDB0000001     1-Methylhistidine
# 2             2  HMDB0000001     1-Methylhistidine
# 20           20  HMDB0000002    1,3-Diaminopropane
# 183         183  HMDB0000014         Deoxycytidine
# 193         193  HMDB0000014         Deoxycytidine
# 194         194  HMDB0000014         Deoxycytidine
# 195         195  HMDB0000014         Deoxycytidine
# 382         382  HMDB0000021          Iodotyrosine
# 385         385  HMDB0000021          Iodotyrosine
# 396         396  HMDB0000022     3-Methoxytyramine
# 397         397  HMDB0000022     3-Methoxytyramine
# 398         398  HMDB0000022     3-Methoxytyramine
# 399         399  HMDB0000022     3-Methoxytyramine
# 438         438  HMDB0000026  Ureidopropionic acid
# 447         447  HMDB0000026  Ureidopropionic acid
# 464         464  HMDB0000026  Ureidopropionic acid
# 474         474  HMDB0000027   Tetrahydrobiopterin
# ...
