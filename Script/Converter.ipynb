# %%
# tera	T	1000000000000	1012
# giga	G	1000000000	109
# mega	M	1000000	106
# kilo	k	1000	103
# hecto	h	100	102
# deca	da	10	101
# (none)	(none)	1	100
# deci	d	0.1	10−1
# centi	c	0.01	10−2
# milli	m	0.001	10−3
# micro	μ	0.000001	10−6
# nano	n	0.000000001	10−9
# pico	p	0.000000000001	10−12

# tera 10 power 12
# giga 10 power 9
# mega 10 power 6
# kilo 10 power	3
#gram

import re

while True:
    unit_list={"T":12,"G":9,"M":6,"k":3,"h":2,"da":1,"d":-1,"c":-2,"m":-3,"μ":-6,"n":-9,"p":-12,"default":0}
    # 1000 1/1000

    # *from/to
#     try:
    from_input = input("Input Value to convert (example 2kg , 2ml , 300km , 200dl) *case sensitive) : ")

    unit_from = re.findall("[a-zA-Z]+", from_input)
    unit_from = unit_from[0]
    
    if(len(unit_from)==1):
        unit_from="default"
    else:
        unit_from = unit_from[-2]
        print(unit_from)
        
    from_value= re.findall('[0-9]+', from_input)
    from_value=float(from_value[0])


#         # get last two character
    unit_to = input("Input unit to convert into {Tera(T),Giga(G),Mega(M),kilo(k),hecto(h),deca(da),deci(d),centi(c),milli(m),micro(μ),nano(n),pico(p)\n example kg , ml , km , dl}")
    
    
    if(len(unit_to)==1):
        unit_to="default"
    else:
        unit_to=unit_to[0]
    # formula = (value input * 10 power from value index)/10 power to value index
    result = (float(from_value) * 10 ** float(unit_list[unit_from])) / (10 ** float(unit_list[unit_to]))

    print(result)

#     except:
#         print("Wrong input format..Format : [xx][unit] x=> number")



# 2 kg to mg
# print(result)

# 200000 mg kg


# split if aplhabet is found


# array 0 times the formula


# array 1 to get the condition
# Out:
# Input Value to convert (example 2kg , 2ml , 300km , 200dl) *case sensitive) : 2kg
# k
# Input unit to convert into {Tera(T),Giga(G),Mega(M),kilo(k),hecto(h),deca(da),deci(d),centi(c),milli(m),micro(μ),nano(n),pico(p)
#  example kg , ml , km , dl}g
# 2000.0
# Input Value to convert (example 2kg , 2ml , 300km , 200dl) *case sensitive) : 2mg
# m
# Input unit to convert into {Tera(T),Giga(G),Mega(M),kilo(k),hecto(h),deca(da),deci(d),centi(c),milli(m),micro(μ),nano(n),pico(p)
#  example kg , ml , km , dl}g
# 0.002
# Input Value to convert (example 2kg , 2ml , 300km , 200dl) *case sensitive) : 2000km
# k
# Input unit to convert into {Tera(T),Giga(G),Mega(M),kilo(k),hecto(h),deca(da),deci(d),centi(c),milli(m),micro(μ),nano(n),pico(p)
#  example kg , ml , km , dl}m
# 2000000.0
# Input Value to convert (example 2kg , 2ml , 300km , 200dl) *case sensitive) : 2ml
# m
# ...
