# %%
import os as os
import pandas as pd
import xml.etree.ElementTree as ET
import numpy as np


abnormal_data=[]
normal_data=[]

# taking 10000 data sample for performance and testing

#read file loop and condition
for i in range(0,10000) :

    if(i<10):
        file_name = "metabolites/hmdb_metabolites-{:02d}.xml".format(i)
    else:
        file_name = "metabolites/hmdb_metabolites-{}.xml".format(i)

    tree = ET.parse(file_name)
    root=tree.getroot()

    
#print("Abnormal Concentration\n ")
    for abnormal in root.findall('abnormal_concentrations'):
        
        for concentration in abnormal.findall('concentration'):
            for attribute in concentration :
#filter for blood specimen
                if(concentration.find('biospecimen').text=="Blood"):

                    if(attribute.tag=='concentration_value'):
                        value=attribute.text
                    if(attribute.tag=='patient_age'):
                        age=attribute.text
                    if(attribute.tag=='patient_sex'):
                        sex=attribute.text
                    if(attribute.tag=='patient_information'):
                        info=attribute.text
                    if(attribute.tag=='comment'):
                        comment=attribute.text
                    else:
                        comment="None"
#append array for creating dataframe
                    toappend=[value,age,sex,info,comment]
                    abnormal_data.append(toappend)
            
           
                        
#print reference(optional)                      
#                     else : 
#                         for reference in attribute.findall('reference'):
#                             print(reference.tag," : ",reference.text)
                    

    for normal in root.findall('normal_concentrations'):
        for concentration in normal.findall('concentration'):
            for attribute in concentration:

                if(concentration.find('biospecimen').text=="Blood"):
                    
                    if(attribute.tag=='concentration_value'):
                        value=attribute.text
                    if(attribute.tag=='subject_age'):
                        age=attribute.text
                    if(attribute.tag=='subject_sex'):
                        sex=attribute.text
                    if(attribute.tag=='subject_condition'):
                        info=attribute.text
                    if(attribute.tag=='comment'):
                        comment=attribute.text
                    else:
                        comment="None"
                    toappend=[value,age,sex,info,comment]
                    
                    normal_data.append(toappend)
                    
# create dataframe and write file in csv format   

# abnormal data
abndf = pd.DataFrame(abnormal_data,columns=['Value(uM)','Patient Age','Patient Sex','Patient Information','Comment'])                    
abndf.to_csv('Abnormal_Concentration.csv',header='False')
abndf.head(30)    
# normal data
ndf = pd.DataFrame(normal_data,columns=['Value(uM)','Subject Age','Subject Sex','Subject Information','Comment'])                    
ndf.to_csv('Normal_Concentration.csv',header='False')
ndf
# Out:
#           Value(uM)            Subject Age Subject Sex  \
# 0      32.7 (13.7)   Adult (>18 years old)      Female
# 1       7.7 +/- 1.9  Adult (>18 years old)      Female
# 2       7.7 +/- 1.9  Adult (>18 years old)      Female
# 3       7.7 +/- 1.9  Adult (>18 years old)      Female
# 4       7.7 +/- 1.9  Adult (>18 years old)        Both
# ...             ...                    ...         ...
# 78672          None                   None        None
# 78673          None                   None        None
# 78674          None                   None        None
# 78675          None                   None        None
# 78676          None                   None        None
#
#                                     Subject Information Comment
# 0                                             Pregnancy    None
# 1                                             Pregnancy    None
# 2                                             Pregnancy    None
# 3                                             Pregnancy    None
# 4                                             Pregnancy    None
# ...                                                 ...     ...
# 78672  Taking drug identified by DrugBank entry DB08819    None
# 78673  Taking drug identified by DrugBank entry DB08819    None
# 78674  Taking drug identified by DrugBank entry DB08819    None
# 78675  Taking drug identified by DrugBank entry DB08820    None
# 78676  Taking drug identified by DrugBank entry DB08820    None
#
# [78677 rows x 5 columns]
